# %%
import os

print(os.getcwd())
print([f for f in os.listdir() if f.lower().endswith(".csv")])
# Out:
# /Users/harshitkala
# []

# %%
import os

print(os.getcwd())
print([f for f in os.listdir() if f.lower().endswith(".csv")])
# Out:
# /Users/harshitkala
# ['e commerce dataset (1).csv']

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("e commerce dataset (1).csv", encoding="latin1")
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.shape
# Out:
# (9994, 21)

# %%
df.tail()
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 9989    9990  CA-2014-110422  1/21/2014  1/23/2014    Second Class
# 9990    9991  CA-2017-121258  2/26/2017   3/3/2017  Standard Class
# 9991    9992  CA-2017-121258  2/26/2017   3/3/2017  Standard Class
# 9992    9993  CA-2017-121258  2/26/2017   3/3/2017  Standard Class
# 9993    9994  CA-2017-119914   5/4/2017   5/9/2017    Second Class
#
#      Customer ID     Customer Name   Segment        Country         City  ...  \
# 9989    TB-21400  Tom Boeckenhauer  Consumer  United States        Miami  ...
# 9990    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9991    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9992    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9993    CC-12220      Chris Cortes  Consumer  United States  Westminster  ...
#
#      Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   str
#  2   Order Date     9994 non-null   str
#  3   Ship Date      9994 non-null   str
#  4   Ship Mode      9994 non-null   str
#  5   Customer ID    9994 non-null   str
#  6   Customer Name  9994 non-null   str
#  7   Segment        9994 non-null   str
#  8   Country        9994 non-null   str
#  9   City           9994 non-null   str
#  10  State          9994 non-null   str
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   str
#  13  Product ID     9994 non-null   str
#  14  Category       9994 non-null   str
#  15  Sub-Category   9994 non-null   str
#  16  Product Name   9994 non-null   str
#  17  Sales          9994 non-null   float64
#  18  Quantity       9994 non-null   int64
# ...

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='str')

# %%
df.dtypes
# Out:
# Row ID             int64
# Order ID             str
# Order Date           str
# Ship Date            str
# Ship Mode            str
# Customer ID          str
# Customer Name        str
# Segment              str
# Country              str
# City                 str
# State                str
# Postal Code        int64
# Region               str
# Product ID           str
# Category             str
# Sub-Category         str
# Product Name         str
# Sales            float64
# Quantity           int64
# Discount         float64
# Profit           float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()[df.isnull().sum() > 0]
# Out:
# Series([], dtype: int64)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
print("Mean:",df["Sales"].mean())
print("Median:",df["Sales"].median())
print("Minimum:",df["Sales"].min())
print("Maximum:",df["Sales"].max())
# Out:
# Mean: 229.85800083049833
# Median: 54.489999999999995
# Minimum: 0.444
# Maximum: 22638.48

# %%
print("Mean:",df["Profit"].mean())
print("Median:",df["Profit"].median())
print("Minimum:",df["Profit"].min())
print("Maximum:",df["Profit"].max())
# Out:
# Mean: 28.65689630778467
# Median: 8.6665
# Minimum: -6599.978
# Maximum: 8399.976

# %%
df[["Sales", "Quantity", "Discount", "Profit"]].agg(
    ["mean", "median", "min", "max"]
)
# Out:
#                Sales   Quantity  Discount       Profit
# mean      229.858001   3.789574  0.156203    28.656896
# median     54.490000   3.000000  0.200000     8.666500
# min         0.444000   1.000000  0.000000 -6599.978000
# max     22638.480000  14.000000  0.800000  8399.976000

# %%
df["Category"].unique()
# Out:
# <StringArray>
# ['Furniture', 'Office Supplies', 'Technology']
# Length: 3, dtype: str

# %%
df.groupby("Category")["Sales"].sum()
# Out:
# Category
# Furniture          741999.7953
# Office Supplies    719047.0320
# Technology         836154.0330
# Name: Sales, dtype: float64

# %%
df.groupby("Category")["Profit"].sum()
# Out:
# Category
# Furniture           18451.2728
# Office Supplies    122490.8008
# Technology         145454.9481
# Name: Profit, dtype: float64

# %%
category_analysis = df.groupby("Category").agg(
    Sales=("Sales", "sum"),
    Profit=("Profit", "sum"),
    Quantity=("Quantity", "sum")
)

category_analysis
# Out:
#                        Sales       Profit  Quantity
# Category
# Furniture        741999.7953   18451.2728      8028
# Office Supplies  719047.0320  122490.8008     22906
# Technology       836154.0330  145454.9481      6939

# %%
df.nlargest(5, "Sales")
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 2697    2698  CA-2014-145317   3/18/2014   3/23/2014  Standard Class
# 6826    6827  CA-2016-118689   10/2/2016   10/9/2016  Standard Class
# 8153    8154  CA-2017-140151   3/23/2017   3/25/2017     First Class
# 2623    2624  CA-2017-127180  10/22/2017  10/24/2017     First Class
# 4190    4191  CA-2017-166709  11/17/2017  11/22/2017  Standard Class
#
#      Customer ID Customer Name      Segment        Country           City  \
# 2697    SM-20320   Sean Miller  Home Office  United States   Jacksonville
# 6826    TC-20980  Tamara Chand    Corporate  United States      Lafayette
# 8153    RB-19360  Raymond Buch     Consumer  United States        Seattle
# 2623    TA-21385  Tom Ashbrook  Home Office  United States  New York City
# 4190    HL-15040  Hunter Lopez     Consumer  United States         Newark
#
#       ... Postal Code   Region       Product ID    Category Sub-Category  \
# ...

# %%
df.nlargest(5, "Profit")[
    ["Order ID", "Product Name", "Category", "Sales", "Profit"]
]
# Out:
#             Order ID                                      Product Name  \
# 6826  CA-2016-118689             Canon imageCLASS 2200 Advanced Copier
# 8153  CA-2017-140151             Canon imageCLASS 2200 Advanced Copier
# 4190  CA-2017-166709             Canon imageCLASS 2200 Advanced Copier
# 9039  CA-2016-117121  GBC Ibimaster 500 Manual ProClick Binding System
# 4098  CA-2014-116904              Ibico EPK-21 Electric Binding System
#
#              Category     Sales     Profit
# 6826       Technology  17499.95  8399.9760
# 8153       Technology  13999.96  6719.9808
# 4190       Technology  10499.97  5039.9856
# 9039  Office Supplies   9892.74  4946.3700
# 4098  Office Supplies   9449.95  4630.4755

# %%
df.nsmallest(5, "Sales")[
    ["Order ID", "Product Name", "Category", "Sales", "Profit"]
]
# Out:
#             Order ID                                       Product Name  \
# 4101  US-2017-102288  Hoover Replacement Belt for Commercial Guardsm...
# 9292  CA-2017-124114           Acco Suede Grain Vinyl Round Ring Binder
# 8658  CA-2016-168361  Avery Durable Slant Ring Binders With Label Ho...
# 4711  CA-2014-112403                      Avery Round Ring Poly Binders
# 2106  US-2014-152723                                  Acco 3-Hole Punch
#
#              Category  Sales  Profit
# 4101  Office Supplies  0.444 -1.1100
# 9292  Office Supplies  0.556 -0.9452
# 8658  Office Supplies  0.836 -1.3376
# 4711  Office Supplies  0.852 -0.5964
# 2106  Office Supplies  0.876 -1.4016
